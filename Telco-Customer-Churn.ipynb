# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Imort CSV file-

# %%
file_path = "C:/Users/TARUN/OneDrive/Desktop/My DSA/My Projects/Telco Customer Churn - python project/Telco-Customer-Churn.csv"
dataset = pd.read_csv(file_path)

# %%
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
dataset.shape
# Out:
# (7043, 21)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # Customizing Columns

# %% [markdown]
# -- Replace blanks with 0 as in Tenure is 0 and no Total Charges are recorderd.
#
# -- Change datatype of Total Charges column from object to float.

# %%
dataset["TotalCharges"] = dataset["TotalCharges"].replace(" ", "0")
dataset["TotalCharges"] = dataset["TotalCharges"].astype("float")

# %% [markdown]
# # Perform EDA (Exploratory Data Analysis)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dataset.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
dataset["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
def conv(value):
    if value == 1:
        return "yes"
    else:
        return "No"
    

dataset["SeniorCitizen"] = dataset["SeniorCitizen"].apply(conv)

# %% [markdown]
# #coverted 0 and 1 value to Yes/No to make it easier to understand.

# %%
dataset.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
plt.figure(figsize = (4,5))
ax = sns.countplot(x = "Churn", data = dataset )
ax.bar_label(ax.containers[0])
plt.title("Count of Customera by Churn")
plt.show()

# %%
gb = dataset.groupby("Churn").agg({'Churn':"count"})
plt.figure(figsize = (4,4))
plt.pie(gb['Churn'], labels = gb.index, autopct= '%1.2f%%')
plt.title("Percentage of Churned Customers")
plt.show()

# %% [markdown]
# #From the given pie chart we can conclude that 26.54% customers are churned out.
#
# #Let's find the reason behind it.

# %%
plt.figure(figsize = (3,3)) 
sns.countplot(x = dataset['gender'], data = dataset, hue = 'Churn') 
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize = (3,4)) 
ax = sns.countplot(x = dataset['SeniorCitizen'], data = dataset)
ax.bar_label(ax.containers[0], fontsize = 9)
plt.title("Churn by Senior Citizen")
plt.show()

# %%
# Preprocessing: Calculate percentage distribution for each group
grouped = dataset.groupby(['SeniorCitizen', 'Churn']).size().unstack()  # Create a pivot table
grouped_percentage = grouped.div(grouped.sum(axis=1), axis=0) * 100  # Convert to percentages

# Plot stacked bar chart
fig, ax = plt.subplots(figsize=(5, 4))
grouped_percentage.plot(kind='bar', stacked=True, ax=ax, color=['#1f77b4', '#ff7f0e'])

# Add percentage labels
for i, bars in enumerate(ax.containers):
    for bar in bars:
        height = bar.get_height()
        if height > 0:  # Only display non-zero percentages
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + height / 2,
                f'{height:.1f}%',
                ha='center', va='center', color='black', fontsize=8
            )

# Add titles and labels
ax.set_title('Churn by Senior Citizen', fontsize=14)
ax.set_xlabel('Senior Citizen', fontsize=12)
ax.set_ylabel('Percentage', fontsize=12)
ax.legend(title='Churn', fontsize=10, bbox_to_anchor = (0.9 , 0.9))
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %% [markdown]
# #Comparative a greater percentage of people in senior sitizen category have churned.

# %%
plt.figure(figsize = (11,4))
sns.histplot(x = 'tenure' , data = dataset, bins = 72, hue = 'Churn')
plt.xlabel("Month Count")
plt.ylabel("Customer Count")
plt.title("Cutomer V/s No. of Stayed Months")
plt.show()

# %% [markdown]
# #A people who have used our services for a long time have stayed and prople who have used our servives for 1 or 2 months have churned.

# %%
from turtle import title


plt.figure(figsize = (5,4)) 
ax = sns.countplot(x = dataset['Contract'], data = dataset, hue = 'Churn')
ax.bar_label(ax.containers[0], fontsize = 8 )
plt.title("Contrct Type Customers")
plt.legend(title = 'Churn', bbox_to_anchor = (0.8 , 0.7))
plt.show()

# %% [markdown]
# #People who have month to month contract are likely to churn then from who have 1 or 2 years of contract.

# %%
ax = dataset['Contract'].value_counts()

plt.pie(x = ax, data = dataset, labels = ax.index, autopct= '%1.2f%%')
plt.title('% of Customer As Per Type of Contracts')
plt.show()

# %%
dataset.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# List of columns to visualize
columns = [
    'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

# Set the number of rows and columns for the subplots
num_cols = 3  # Number of columns in the grid
num_rows = (len(columns) + num_cols - 1) // num_cols  # Calculate rows to fit all subplots

# Create a figure with subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 4), constrained_layout=True)
axes = axes.flatten()  # Flatten the 2D axes array for easier iteration

# Plot each column as a count plot
for i, column in enumerate(columns):
    sns.countplot(data=dataset, x=column, ax=axes[i], palette="Set2", hue = dataset['Churn'])
    axes[i].set_title(f'Distribution of {column}', fontsize=12)
    axes[i].set_xlabel(column, fontsize=10)
    axes[i].set_ylabel('Count', fontsize=10)
    axes[i].tick_params(axis='x')

# Hide any unused subplots
for j in range(len(columns), len(axes)):
    axes[j].axis('off')


plt.show()

# %% [markdown]
# From the provided graphs, here's an analysis of the insights for each of the columns represented:
#
# ---
#
# #1. PhoneService
# - The majority of customers have phone service.
# - Customers with phone service are more likely to churn compared to those without it.
#
# ---
#
# #2. MultipleLines**
# - Most customers either have no additional phone lines or only a single line.
# - Churn is higher among customers with additional phone lines compared to those without.
#
# ---
#
# #3. InternetService
# - A significant number of customers use "Fiber optic" internet, followed by "DSL."
# - Customers with "Fiber optic" internet exhibit higher churn rates compared to "DSL" users.
# - Those without internet service show the least churn.
#
# ---
#
# #4. OnlineSecurity
# - Many customers do not have online security services.
# - Churn is significantly higher among customers who lack online security compared to those with the service.
#
# ---
#
# #5. OnlineBackup
# - Similar to OnlineSecurity, a large number of customers do not have online backup services.
# - Customers without online backup services are more likely to churn compared to those with it.
#
# ---
#
# #6. DeviceProtection
# - Many customers do not have device protection services.
# - Churn rates are higher for customers who do not have device protection compared to those who do.
#
# ---
#
# #7. TechSupport
# - A significant portion of customers lack technical support services.
# - Customers without tech support are more likely to churn, indicating the importance of offering support.
#
# ---
#
# #8. StreamingTV
# - A large number of customers either subscribe to streaming TV services or do not use them due to a lack of internet service.
# - Customers with streaming TV services have a slightly higher churn rate than those without.
#
# ---
#
# #9. StreamingMovies
# - The pattern is similar to StreamingTV, where many customers either subscribe or do not use streaming movies due to no internet service.
# - Churn is higher among customers with streaming movies subscriptions.
#
# ---

# %%
plt.figure(figsize = (6,4)) 
ax = sns.countplot(x = dataset['PaymentMethod'], data = dataset, hue = 'Churn')

ax.bar_label(ax.containers[0], fontsize = 9)
ax.bar_label(ax.containers[1], fontsize = 9)

labels = [label.get_text().replace(' ', '\n') for label in ax.get_xticklabels()]
ax.set_xticklabels(labels)

plt.title("Churned Customes by Payment Method")
plt.legend(bbox_to_anchor = (1,1))
plt.show()
# Out:
# C:\Users\TARUN\AppData\Local\Temp\ipykernel_20988\480934030.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)

# %% [markdown]
# #Customers likely to use churn when they using 'Electronic Check' as a payment method.

# %%
pd = dataset[(dataset['Churn'] == 'Yes') & (dataset['tenure'] >= 48)][['customerID' , 'Churn' , 'tenure']]
pd.attrs["title"] = "Top Churned Customers\nstayed More than 4 years"

Sort_pd = pd.sort_values(by = 'tenure' , ascending = False)

print(pd.attrs["title"])
Sort_pd
# Out:
# Top Churned Customers
# stayed More than 4 years
#       customerID Churn  tenure
# 6424  6034-ZRYCV   Yes      72
# 4610  2889-FPWRM   Yes      72
# 4513  8580-QVLOC   Yes      72
# 3890  3886-CERTZ   Yes      72
# 3439  0917-EZOLA   Yes      72
# ...          ...   ...     ...
# 3924  7716-YTYHG   Yes      48
# 5216  3034-ZBEQN   Yes      48
# 4875  2302-ANTDP   Yes      48
# 6680  9412-ARGBX   Yes      48
# 6952  6394-MFYNG   Yes      48
#
# [222 rows x 3 columns]

# %% [markdown]
# #222 Churned customers are stayed with company more that 4 years.
#
# #Should provides them some free servives as token of believing.
